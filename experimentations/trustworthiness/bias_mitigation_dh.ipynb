# %%
import yaml
import pandas as pd
import digitalhub as dh

from fairness.holisticAI.src.data_preparation import *
from fairness.holisticAI.src.modelling import *
from fairness.holisticAI.src.operationalization import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 import digitalhub as dh
#       5 from fairness.holisticAI.src.data_preparation import *
# ----> 6 from fairness.holisticAI.src.modelling import *
#       7 from fairness.holisticAI.src.operationalization import *
#
# File ~/ai_product_card_templates/experimentations/trustworthiness/fairness/holisticAI/src/modelling.py:9
#       6 from interpret import show
#       8 from artifact_types import Data, Configuration, Report, Model
# ----> 9 from fairness.holisticAI.src.utils import *
#      10 from fairness.holisticAI.src.data_preparation import *
#      12 from scipy.stats import uniform
#
# File ~/ai_product_card_templates/experimentations/trustworthiness/fairness/holisticAI/src/utils.py:7
#       5 from holisticai.bias.metrics import disparate_impact, statistical_parity, average_odds_diff
#       6 from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
# ----> 7 from model_card_toolkit import ModelCardToolkit
#       9 # visualization
#      10 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'model_card_toolkit'

# %% [markdown]
# # Create AI product project

# %%
project = dh.get_or_create_project(name="fair_hiring_tabular")

# %% [markdown]
# ## Data preparation stage

# %% [markdown]
# ### Data preprocessing

# %%
from data_preparation import *

# %% [markdown]
# ### Data profiling

# %% [markdown]
# ## Modelling stage

# %% [markdown]
# ### Model training

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# ## Operationalization stage

# %% [markdown]
# ### Model deployment

# %% [markdown]
# # Pipeline fairness
# (fairness+ robustness + ... ?)

# %% [markdown]
# # Quality Assurance
# (Quality assurance automation?)
# (Auditing and compliance check)
